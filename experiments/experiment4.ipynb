# %%
import sys
import os

from glob import glob
from torch.utils.data import Dataset, DataLoader
from torch.nn.utils.rnn import pad_sequence

from dotenv import load_dotenv


load_dotenv()
# Out:
# True

# %%
import pickle

# Function to save model as pickle file
def save_model_pickle(model, path):
    with open(path, "wb") as f:
        pickle.dump(model, f)
    print("Model saved successfully as pickle file!")

# Function to load model from pickle file
def load_model_pickle(path):
    with open(path, "rb") as f:
        model = pickle.load(f)
    model.eval()
    print("Model loaded successfully from pickle file!")
    return model


# Collate function to pad variable-length sequences
def collate_fn(batch):
    features, labels = zip(*batch)
    features_padded = pad_sequence(features, batch_first=True, padding_value=0)
    labels_padded = pad_sequence(labels, batch_first=True, padding_value=0)
    return features_padded, labels_padded

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from glob import glob
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, confusion_matrix
from vap_sound.utils.extract_mfcc_torchaudio import MFCC_EXTRACTION

MFCC_SAMPLE_RATE = 16000
FUTURE_OFFSET = 10
HOP_LENGTH = 160
N_MFCC_PER_FRAME = 40
SEQ_LENGTH = 100    
BATCH_SIZE = 32
LEARNING_RATE = 0.001
NUM_EPOCHS = 15
BATCH_FILE_SIZE = 1000


MODEL_PATH = "vap_model_4.pkl"
LOG_MODEL_EVALUATION = "../logs/model_evaluation_4.log"
LOG_MODEL_PREDICTION = "../logs/model_prediction_4.log"

# Create logs directory if missing
os.makedirs("../logs", exist_ok=True)

class ImprovedVAPModel(nn.Module):
    def __init__(self, input_dim=40, proj_dim=64, transformer_heads=8, transformer_layers=4,
                 lstm_hidden_dim=256, lstm_layers=2, output_dim=1, dropout_prob=0.3):
        super(ImprovedVAPModel, self).__init__()

        self.input_proj = nn.Linear(input_dim, proj_dim)
        self.transformer = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model=proj_dim, nhead=transformer_heads, dropout=dropout_prob),
            num_layers=transformer_layers
        )
        self.lstm = nn.LSTM(input_size=proj_dim, hidden_size=lstm_hidden_dim, num_layers=lstm_layers,
                            batch_first=True, bidirectional=True, dropout=dropout_prob)
        self.layer_norm = nn.LayerNorm(2 * lstm_hidden_dim)
        self.dropout = nn.Dropout(dropout_prob)
        self.fc = nn.Linear(2 * lstm_hidden_dim, output_dim)

    def forward(self, x):
        x = self.input_proj(x)
        x = self.transformer(x)
        x, _ = self.lstm(x)
        x = self.layer_norm(x)
        x = self.dropout(x)
        x = self.fc(x)  # (batch, seq, 1)
        return x

class VAPDataset(Dataset):
    def __init__(self, data_df, seq_length=100):
        self.seq_length = seq_length
        self.features = [torch.tensor(f, dtype=torch.float32) for f in data_df['features']]
        self.labels = [torch.tensor(l, dtype=torch.float32) for l in data_df['labels']]

    def __len__(self):
        return len(self.features)

    def __getitem__(self, idx):
        feature, label = self.features[idx], self.labels[idx]
        if feature.shape[0] > self.seq_length:
            feature, label = feature[-self.seq_length:], label[-self.seq_length:]
        else:
            pad_len = self.seq_length - feature.shape[0]
            feature = torch.cat([torch.zeros(pad_len, feature.shape[1]), feature], dim=0)
            label = torch.cat([torch.zeros(pad_len, label.shape[1]), label], dim=0)
        return feature, label


def train_model(training_data, batch_size=16, epochs=10, seq_length=100, learning_rate=1e-3, model=None):
    if os.path.exists(MODEL_PATH):
        model = load_model_pickle(MODEL_PATH)

    train_dataset = VAPDataset(training_data, seq_length)
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    criterion = nn.BCEWithLogitsLoss(pos_weight=torch.tensor([5.0]))

    for epoch in range(epochs):
        model.train()
        train_loss, val_loss = 0.0, 0.0

        for features, labels in train_loader:
            optimizer.zero_grad()
            outputs = model(features)

            if labels.shape[-1] == 2:
                labels = labels[:, :, 1:]  # keep class 1 (speech)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

        model.eval()
        with torch.no_grad():
            for features, labels in train_loader:
                outputs = model(features)
                if labels.shape[-1] == 2:
                    labels = labels[:, :, 1:]
                loss = criterion(outputs, labels)
                val_loss += loss.item()

        print(f"Epoch {epoch+1}/{epochs}, Train Loss: {train_loss/len(train_loader):.4f}, Val Loss: {val_loss/len(train_loader):.4f}")
    save_model_pickle(model, MODEL_PATH)
    print("Training complete!")


def evaluate_model(model, test_loader, output_file, metrics_file):
    model.eval()
    all_preds, all_labels = [], []
    criterion = nn.BCEWithLogitsLoss(pos_weight=torch.tensor([5.0]))

    with torch.no_grad(), open(output_file, "w") as f_pred, open(metrics_file, "w") as f_metrics:
        for features, labels in test_loader:
            outputs = model(features)
            if labels.shape[-1] == 2:
                labels = labels[:, :, 1:]

            min_len = min(outputs.shape[1], labels.shape[1])
            outputs = outputs[:, :min_len, :]
            labels = labels[:, :min_len, :]

            loss = criterion(outputs, labels)
            preds = (torch.sigmoid(outputs) > 0.5).float()

            all_preds.extend(preds.cpu().numpy().flatten())
            all_labels.extend(labels.cpu().numpy().flatten())

            for p, l in zip(preds, labels):
                f_pred.write(f"Predicted: {p.tolist()}\nActual: {l.tolist()}\n\n")

        acc = accuracy_score(all_labels, all_preds)
        conf_matrix = confusion_matrix(all_labels, all_preds)

        f_metrics.write(f"Test Accuracy: {acc:.4f}\n")
        f_metrics.write(f"Confusion Matrix:\n{conf_matrix}\n")

        print(f"Test Accuracy: {acc:.4f}")
        print("Confusion Matrix:")
        print(conf_matrix)

        sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues")
        plt.xlabel("Predicted")
        plt.ylabel("Actual")
        plt.title("Confusion Matrix")
        plt.show()

# ========== MAIN TRAINING LOOP ==========
data_dir = "/Users/shanujha/Desktop/voice_activity_prediction/voice_data_mozilla/en/clips"
audio_files = glob(os.path.join(data_dir, "*.mp3"))
file_df = pd.DataFrame({"file_paths": audio_files, "processed": [0]*len(audio_files)})

mfcc_extraction = MFCC_EXTRACTION()
model1 = ImprovedVAPModel()
total = len(file_df) // BATCH_FILE_SIZE

for i in range(0, len(file_df)-BATCH_FILE_SIZE, BATCH_FILE_SIZE):
    train_files = file_df['file_paths'][i:i+BATCH_FILE_SIZE]
    training_data = mfcc_extraction.extract_mfcc_features(
        audio_files=train_files,
        target_sample_rate=MFCC_SAMPLE_RATE,
        future_offset=FUTURE_OFFSET,
        n_mfcc=N_MFCC_PER_FRAME,
        hop_length=HOP_LENGTH
    )
    train_model(training_data, batch_size=BATCH_SIZE, epochs=NUM_EPOCHS,
                seq_length=SEQ_LENGTH, learning_rate=LEARNING_RATE, model=model1)

    random_idx = np.random.randint(0, len(file_df)-BATCH_FILE_SIZE)
    eval_files = file_df['file_paths'][random_idx:random_idx+300]
    eval_data = mfcc_extraction.extract_mfcc_features(
        audio_files=eval_files,
        target_sample_rate=MFCC_SAMPLE_RATE,
        future_offset=FUTURE_OFFSET,
        n_mfcc=N_MFCC_PER_FRAME,
        hop_length=HOP_LENGTH
    )
    eval_dataset = VAPDataset(eval_data)
    eval_dataloader = DataLoader(eval_dataset, batch_size=16, shuffle=True)
    evaluate_model(model1, eval_dataloader, output_file=LOG_MODEL_EVALUATION, metrics_file=LOG_MODEL_PREDICTION)

    print(f"BATCH {i // BATCH_FILE_SIZE + 1} of {total} completed")

print("Training Completed")
# Out:
# INFO:speechbrain.utils.fetching:Fetch hyperparams.yaml: Fetching from HuggingFace Hub 'speechbrain/vad-crdnn-libriparty' if not cached
# INFO:speechbrain.utils.fetching:Fetch custom.py: Fetching from HuggingFace Hub 'speechbrain/vad-crdnn-libriparty' if not cached
# INFO:speechbrain.utils.fetching:Fetch model.ckpt: Fetching from HuggingFace Hub 'speechbrain/vad-crdnn-libriparty' if not cached
# INFO:speechbrain.utils.fetching:Fetch mean_var_norm.ckpt: Fetching from HuggingFace Hub 'speechbrain/vad-crdnn-libriparty' if not cached
# INFO:speechbrain.utils.parameter_transfer:Loading pretrained files for: model, mean_var_norm
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/transformer.py:385: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(
# /Users/shanujha/Desktop/voice_activity_prediction/src/vap_sound/utils/extract_mfcc_torchaudio.py:34: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   speech_probs = torch.tensor(speech_probs).squeeze(0)
# Model loaded successfully from pickle file!
# Epoch 1/15, Train Loss: 0
# Model saved successfully as pickle file!
# Training complete!
# Test Accuracy: 0.4092
# Confusion Matrix:
# [[ 5746 11628]
#  [ 6095  6531]]
# BATCH 6 of 27 completed
# /Users/shanujha/Desktop/voice_activity_prediction/src/vap_sound/utils/extract_mfcc_torchaudio.py:34: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   speech_probs = torch.tensor(speech_probs).squeeze(0)
# Model loaded successfully from pickle file!
# Epoch 1/15, Train Loss: 0.8882, Val Loss: 0.9198
# Epoch 2/15, Train Loss: 0.9493, Val Loss: 0.9613
# Epoch 3/15, Train Loss: 0.9312, Val Loss: 0.9473
# Epoch 4/15, Train Loss: 0.8922, Val Loss: 0.9515
# Epoch 5/15, Train Loss: 0.9299, Val Loss: 0.9244
# Epoch 6/15, Train Loss: 0.9041, Val Loss: 0.9072
# Epoch 7/15, Train Loss: 0.9096, Val Loss: 0.9077
# Epoch 8/15, Train Loss: 0.9252, Val Loss: 0.9254
# Epoch 9/15, Train Loss: 0.8922, Val Loss: 0.9365
# Epoch 10/15, Train Loss: 0.8886, Val Loss: 0.9161
# Epoch 11/15, Train Loss: 0.8982, Val Loss: 0.8945
# Epoch 12/15, Train Loss: 0.9029, Val Loss: 0.9070
# Epoch 13/15, Train Loss: 0.9063, Val Loss: 0.9181
# Epoch 14/15, Train Loss: 0.9133, Val Loss: 0.9159
# Epoch 15/15, Train Loss: 0.9145, Val Loss: 0.9163
# Model saved successfully as pickle file!
# Training complete!
# Test Accuracy: 0.4221
# Confusion Matrix:
# [[ 6933 11553]
#  [ 5784  5730]]
# BATCH 7 of 27 completed
# /Users/shanujha/Desktop/voice_activity_prediction/src/vap_sound/utils/extract_mfcc_torchaudio.py:34: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   speech_probs = torch.tensor(speech_probs).squeeze(0)
# Model loaded successfully from pickle file!
# Epoch 1/15, Train Loss: 0.9114, Val Loss: 0.9221
# Epoch 2/15, Train Loss: 0.9391, Val Loss: 0.9474
# Epoch 3/15, Train Loss: 0.9729, Val Loss: 1.0615
# Epoch 4/15, Train Loss: 1.0226, Val Loss: 1.0690
# Epoch 5/15, Train Loss: 1.0031, Val Loss: 1.0807
# Epoch 6/15, Train Loss: 0.9680, Val Loss: 1.0808
# Epoch 7/15, Train Loss: 1.0227, Val Loss: 1.1071
# Epoch 8/15, Train Loss: 1.1597, Val Loss: 1.2397
# Epoch 9/15, Train Loss: 1.1957, Val Loss: 1.1955
# Epoch 10/15, Train Loss: 1.2073, Val Loss: 1.1994
# Epoch 11/15, Train Loss: 1.1971, Val Loss: 1.2017
# Epoch 12/15, Train Loss: 1.1978, Val Loss: 1.1995
# Epoch 13/15, Train Loss: 1.2060, Val Loss: 1.2077
# Epoch 14/15, Train Loss: 1.2012, Val Loss: 1.2004
# Epoch 15/15, Train Loss: 1.2036, Val Loss: 1.1989
# Model saved successfully as pickle file!
# Training complete!
# Test Accuracy: 0.4053
# Confusion Matrix:
# [[ 6333 12030]
#  [ 5812  5825]]
# BATCH 8 of 27 completed
# /Users/shanujha/Desktop/voice_activity_prediction/src/vap_sound/utils/extract_mfcc_torchaudio.py:34: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   speech_probs = torch.tensor(speech_probs).squeeze(0)
# Model loaded successfully from pickle file!
# Epoch 1/15, Train Loss: 1.2095, Val Loss: 1.2194
# Epoch 2/15, Train Loss: 1.2170, Val Loss: 1.2095
# Epoch 3/15, Train Loss: 1.2181, Val Loss: 1.2136
# Epoch 4/15, Train Loss: 1.2115, Val Loss: 1.2087
# Epoch 5/15, Train Loss: 1.2200, Val Loss: 1.2096
# Epoch 6/15, Train Loss: 1.2157, Val Loss: 1.2062
# Epoch 7/15, Train Loss: 1.2086, Val Loss: 1.2223
# Epoch 8/15, Train Loss: 1.2195, Val Loss: 1.2070
# Epoch 9/15, Train Loss: 1.2152, Val Loss: 1.2165
# Epoch 10/15, Train Loss: 1.2138, Val Loss: 1.2090
# Epoch 11/15, Train Loss: 1.2161, Val Loss: 1.2150
# Epoch 12/15, Train Loss: 1.2130, Val Loss: 1.2100
# Epoch 13/15, Train Loss: 1.2130, Val Loss: 1.2063
# Epoch 14/15, Train Loss: 1.2107, Val Loss: 1.2117
# Epoch 15/15, Train Loss: 1.2128, Val Loss: 1.2100
# Model saved successfully as pickle file!
# Training complete!
# Test Accuracy: 0.4236
# Confusion Matrix:
# [[ 6057 10794]
#  [ 6498  6651]]
# BATCH 9 of 27 completed
# /Users/shanujha/Desktop/voice_activity_prediction/src/vap_sound/utils/extract_mfcc_torchaudio.py:34: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   speech_probs = torch.tensor(speech_probs).squeeze(0)
# Model loaded successfully from pickle file!
# Epoch 1/15, Train Loss: 1.2059, Val Loss: 1.1986
# Epoch 2/15, Train Loss: 1.2093, Val Loss: 1.2034
# Epoch 3/15, Train Loss: 1.2059, Val Loss: 1.2119
# Epoch 4/15, Train Loss: 1.2127, Val Loss: 1.2015
# Epoch 5/15, Train Loss: 1.2032, Val Loss: 1.2056
# Epoch 6/15, Train Loss: 1.2052, Val Loss: 1.1995
# Epoch 7/15, Train Loss: 1.2042, Val Loss: 1.1997
# Epoch 8/15, Train Loss: 1.2019, Val Loss: 1.2033
# Epoch 9/15, Train Loss: 1.2074, Val Loss: 1.1988
# Epoch 10/15, Train Loss: 1.2053, Val Loss: 1.2111
# Epoch 11/15, Train Loss: 1.2092, Val Loss: 1.1979
# Epoch 12/15, Train Loss: 1.2047, Val Loss: 1.2001
# Epoch 13/15, Train Loss: 1.1975, Val Loss: 1.2042
# Epoch 14/15, Train Loss: 1.2043, Val Loss: 1.2101
# Epoch 15/15, Train Loss: 1.2051, Val Loss: 1.2013
# Model saved successfully as pickle file!
# Training complete!
# Test Accuracy: 0.4070
# Confusion Matrix:
# [[ 4994 12808]
#  [ 4982  7216]]
# BATCH 10 of 27 completed
# /Users/shanujha/Desktop/voice_activity_prediction/src/vap_sound/utils/extract_mfcc_torchaudio.py:34: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   speech_probs = torch.tensor(speech_probs).squeeze(0)
# Model loaded successfully from pickle file!
# Epoch 1/15, Train Loss: 1.2059, Val Loss: 1.2056
# Epoch 2/15, Train Loss: 1.1996, Val Loss: 1.2171
# Epoch 3/15, Train Loss: 1.2081, Val Loss: 1.1989
# Epoch 4/15, Train Loss: 1.1993, Val Loss: 1.2172
# Epoch 5/15, Train Loss: 1.2021, Val Loss: 1.2012
# Epoch 6/15, Train Loss: 1.2043, Val Loss: 1.1975
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 173
#     165 train_files = file_df['file_paths'][i:i+BATCH_FILE_SIZE]
#     166 training_data = mfcc_extraction.extract_mfcc_features(
#     167     audio_files=train_files,
#     168     target_sample_rate=MFCC_SAMPLE_RATE,
#    (...)
#     171     hop_length=HOP_LENGTH
#     172 )
# --> 173 train_model(training_data, batch_size=BATCH_SIZE, epochs=NUM_EPOCHS,
#     174             seq_length=SEQ_LENGTH, learning_rate=LEARNING_RATE, model=model1)
#     176 random_idx = np.random.randint(0, len(file_df)-BATCH_FILE_SIZE)
#     177 eval_files = file_df['file_paths'][random_idx:random_idx+300]
#
# Cell In[12], line 104, in train_model(training_data, batch_size, epochs, seq_length, learning_rate, model)
#     102 with torch.no_grad():
#     103     for features, labels in train_loader:
# --> 104         outputs = model(features)
#     105         if labels.shape[-1] == 2:
#     106             labels = labels[:, :, 1:]
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# Cell In[12], line 51, in ImprovedVAPModel.forward(self, x)
#      49 x = self.input_proj(x)
#      50 x = self.transformer(x)
# ---> 51 x, _ = self.lstm(x)
#      52 x = self.layer_norm(x)
#      53 x = self.dropout(x)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/rnn.py:1124, in LSTM.forward(self, input, hx)
#    1121         hx = self.permute_hidden(hx, sorted_indices)
#    1123 if batch_sizes is None:
# -> 1124     result = _VF.lstm(
#    1125         input,
#    1126         hx,
#    1127         self._flat_weights,  # type: ignore[arg-type]
#    1128         self.bias,
#    1129         self.num_layers,
#    1130         self.dropout,
#    1131         self.training,
#    1132         self.bidirectional,
#    1133         self.batch_first,
#    1134     )
#    1135 else:
#    1136     result = _VF.lstm(
#    1137         input,
#    1138         batch_sizes,
#    (...)
#    1145         self.bidirectional,
#    1146     )
#
# KeyboardInterrupt:
