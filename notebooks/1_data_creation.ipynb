# %%
import torch
import torchaudio
import torchaudio.transforms as T
import pandas as pd


# Function to extract features and save to CSV
def extract_features_to_csv(audio_files, csv_file, sample_rate=16000, future_offset=10):
    mfcc_transform = T.MFCC(sample_rate=sample_rate, n_mfcc=40, 
                            melkwargs={"n_fft": 400, "hop_length": 160, "n_mels": 40})
    vad = torchaudio.transforms.Vad(sample_rate=sample_rate)
    
    data_list = []
    for file in audio_files:
        waveform, sr = torchaudio.load(file, format='mp3')
        waveform = torchaudio.functional.resample(waveform, orig_freq=sr, new_freq=sample_rate)
        mfcc = mfcc_transform(waveform).squeeze(0).T  # Convert to (time_steps, mfcc_dim)
        vad_labels = vad(waveform).squeeze(0)  # Generate VAD labels
        vad_labels = (vad_labels > 0).float().unsqueeze(1).expand(-1, 2)  # Binary labels
        
        min_length = min(mfcc.shape[0], vad_labels.shape[0])
        if min_length == 0:
            continue  # Skip empty entries
        
        mfcc = mfcc[:min_length, :]
        vad_labels = vad_labels[:min_length, :]
        
        y_projected = torch.zeros_like(vad_labels)
        if min_length > future_offset:
            y_projected[:-future_offset, :] = vad_labels[future_offset:, :]
        else:
            y_projected = vad_labels
        
        data_list.append([mfcc.tolist(), y_projected.tolist()])
    
    df = pd.DataFrame(data_list, columns=['features', 'labels'])
    df.to_csv(csv_file, index=False)
    print(f"Dataset saved to {csv_file}")

# %%
from glob import glob
import os
import pandas as pd

data_dir = "/Users/shanujha/Desktop/voice_activity_prediction/voice_data_mozilla/en/clips/"
audio_files = glob(os.path.join(data_dir, "*.mp3"))

if not os.path.exists("../mfcc_extract_csv/"):
    os.makedirs("../mfcc_extract_csv/")

batch_size = 100

batch = 1
for i in range(int(len(audio_files)/batch_size) + 1):
    dataset = extract_features_to_csv(audio_files[i*batch_size:(i+1)*batch_size], f"../mfcc_extract_csv/dataset_{batch}.csv")
    # df = pd.DataFrame(dataset.data, columns=['mfcc', 'label'])
    # df.to_csv(f"processed_data/dataset_{batch}.csv")
    # print(f"Dataset {i} length: {len(dataset)}")
    print(f"Dataset {i} saved successfully!")
    batch += 1
# Out:
# Dataset saved to ../mfcc_extract_csv/dataset_1.csv
# Dataset 0 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_2.csv
# Dataset 1 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_3.csv
# Dataset 2 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_4.csv
# Dataset 3 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_5.csv
# Dataset 4 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_6.csv
# Dataset 5 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_7.csv
# Dataset 6 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_8.csv
# Dataset 7 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_9.csv
# Dataset 8 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_10.csv
# Dataset 9 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_11.csv
# Dataset 10 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_12.csv
# Dataset 11 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_13.csv
# Dataset 12 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_14.csv
# Dataset 13 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_15.csv
# Dataset 14 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_16.csv
# Dataset 15 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_17.csv
# Dataset 16 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_18.csv
# Dataset 17 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_19.csv
# Dataset 18 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_20.csv
# Dataset 19 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_21.csv
# Dataset 20 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_22.csv
# Dataset 21 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_23.csv
# Dataset 22 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_24.csv
# Dataset 23 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_25.csv
# Dataset 24 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_26.csv
# Dataset 25 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_27.csv
# Dataset 26 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_28.csv
# Dataset 27 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_29.csv
# Dataset 28 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_30.csv
# Dataset 29 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_31.csv
# Dataset 30 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_32.csv
# Dataset 31 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_33.csv
# Dataset 32 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_34.csv
# Dataset 33 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_35.csv
# Dataset 34 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_36.csv
# Dataset 35 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_37.csv
# Dataset 36 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_38.csv
# Dataset 37 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_39.csv
# Dataset 38 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_40.csv
# Dataset 39 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_41.csv
# Dataset 40 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_42.csv
# Dataset 41 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_43.csv
# Dataset 42 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_44.csv
# Dataset 43 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_45.csv
# Dataset 44 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset
saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_163.csv
# Dataset 162 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_164.csv
# Dataset 163 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_165.csv
# Dataset 164 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_166.csv
# Dataset 165 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_167.csv
# Dataset 166 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_168.csv
# Dataset 167 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_169.csv
# Dataset 168 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_170.csv
# Dataset 169 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_171.csv
# Dataset 170 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_172.csv
# Dataset 171 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_173.csv
# Dataset 172 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_174.csv
# Dataset 173 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_175.csv
# Dataset 174 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_176.csv
# Dataset 175 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_177.csv
# Dataset 176 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_178.csv
# Dataset 177 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_179.csv
# Dataset 178 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_180.csv
# Dataset 179 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_181.csv
# Dataset 180 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_182.csv
# Dataset 181 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_183.csv
# Dataset 182 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_184.csv
# Dataset 183 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_185.csv
# Dataset 184 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_186.csv
# Dataset 185 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_187.csv
# Dataset 186 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_188.csv
# Dataset 187 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_189.csv
# Dataset 188 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_190.csv
# Dataset 189 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_191.csv
# Dataset 190 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_192.csv
# Dataset 191 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_193.csv
# Dataset 192 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_194.csv
# Dataset 193 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_195.csv
# Dataset 194 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_196.csv
# Dataset 195 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_197.csv
# Dataset 196 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_198.csv
# Dataset 197 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_199.csv
# Dataset 198 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_200.csv
# Dataset 199 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_201.csv
# Dataset 200 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_202.csv
# Dataset 201 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_203.csv
# Dataset 202 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_204.csv
# Dataset 203 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_205.csv
# Dataset 204 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_206.csv
# Dataset 205 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_207.csv
# Dataset 206 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_208.csv
# Dataset 207 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_209.csv
# Dataset 208 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_210.csv
# Dataset 209 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_211.csv
# Dataset 210 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_212.csv
# Dataset 211 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_213.csv
# Dataset 212 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_214.csv
# Dataset 213 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_215.csv
# Dataset 214 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_216.csv
# Dataset 215 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_217.csv
# Dataset 216 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_218.csv
# Dataset 217 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_219.csv
# Dataset 218 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_220.csv
# Dataset 219 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_221.csv
# Dataset 220 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_222.csv
# Dataset 221 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_223.csv
# Dataset 222 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_224.csv
# Dataset 223 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_225.csv
# Dataset 224 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_226.csv
# Dataset 225 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_227.csv
# Dataset 226 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_228.csv
# Dataset 227 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_229.csv
# Dataset 228 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_230.csv
# Dataset 229 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_231.csv
# Dataset 230 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_232.csv
# Dataset 231 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_233.csv
# Dataset 232 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_234.csv
# Dataset 233 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_235.csv
# Dataset 234 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_236.csv
# Dataset 235 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_237.csv
# Dataset 236 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_238.csv
# Dataset 237 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_239.csv
# Dataset 238 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_240.csv
# Dataset 239 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_241.csv
# Dataset 240 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_242.csv
# Dataset 241 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_243.csv
# Dataset 242 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_244.csv
# Dataset 243 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_245.csv
# Dataset 244 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_246.csv
# Dataset 245 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_247.csv
# Dataset 246 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_248.csv
# Dataset 247 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_249.csv
# Dataset 248 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_250.csv
# Dataset 249 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_251.csv
# Dataset 250 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_252.csv
# Dataset 251 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_253.csv
# Dataset 252 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_254.csv
# Dataset 253 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_255.csv
# Dataset 254 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_256.csv
# Dataset 255 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_257.csv
# Dataset 256 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_258.csv
# Dataset 257 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_259.csv
# Dataset 258 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_260.csv
# Dataset 259 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_261.csv
# Dataset 260 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_262.csv
# Dataset 261 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_263.csv
# Dataset 262 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_264.csv
# Dataset 263 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_265.csv
# Dataset 264 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_266.csv
# Dataset 265 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_267.csv
# Dataset 266 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_268.csv
# Dataset 267 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_269.csv
# Dataset 268 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_270.csv
# Dataset 269 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_271.csv
# Dataset 270 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_272.csv
# Dataset 271 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_273.csv
# Dataset 272 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_274.csv
# Dataset 273 saved successfully!
# Dataset saved to ../mfcc_extract_csv/dataset_275.csv
# Dataset 274 saved successfully!

# %%
if not os.path.exists("../hello"):
    os.makedirs("../hello")
